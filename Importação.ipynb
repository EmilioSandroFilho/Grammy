# %%
# !pip3 install pandas

# %%
import pandas as pd

# %%
best_artists_RS = pd.read_csv('best artists_RS.csv')
grammys_best_album = pd.read_csv('grammys-best album.csv')
grammys_best_record = pd.read_csv('grammys-best record.csv')
money_makers_bb = pd.read_csv('money-makers-bb.csv')
richest_musicians_by_year = pd.read_csv('richest musicians by year.csv')

# %%
best_artists_RS.head(20)
# Out:
#     Rolling Stone Magazine Rank              Artist Racial/Ethnic group  \
# 0                             1         The Beatles      White/European
# 1                             2           Bob Dylan      White/European
# 2                             3       Elvis Presley      White/European
# 3                             4  The Rolling Stones      White/European
# 4                             5         Chuck Berry       Black/African
# 5                             6        Jimi Hendrix       Black/African
# 6                             7         James Brown       Black/African
# 7                             8      Little Richard       Black/African
# 8                             9     Aretha Franklin       Black/African
# 9                            10         Ray Charles       Black/African
# 10                           11          Bob Marley       Black/African
# 11                           12          Beach Boys      White/European
# ...

# %%
best_artists_RS.describe()
# Out:
#        Rolling Stone Magazine Rank  Main Grammy awards  \
# count                   100.000000          100.000000
# mean                     50.500000            0.340000
# std                      29.011492            0.997168
# min                       1.000000            0.000000
# 25%                      25.750000            0.000000
# 50%                      50.500000            0.000000
# 75%                      75.250000            0.000000
# max                     100.000000            6.000000
#
#        Main Grammy Nominations  Total Awards  Total Nominations  UK number 1's
# count               100.000000    100.000000         100.000000     100.000000
# mean                  1.440000      3.700000          11.710000       1.390000
# std                   2.652691      5.786609          15.729593       3.422726
# min                   0.000000      0.000000           0.000000       0.000000
# ...

# %%
grammys_best_album.head(20)
# Out:
#       Year                Artist                                   Work  \
# 0   1959.0         Henry Mancini              The Music from Peter Gunn
# 1   1960.0         Frank Sinatra                    Come Dance with Me!
# 2   1961.0           Bob Newhart    The Button-Down Mind of Bob Newhart
# 3   1962.0          Judy Garland                  Judy at Carnegie Hall
# 4   1963.0         Vaughn Meader                       The First Family
# 5   1964.0      Barbra Streisand             The Barbra Streisand Album
# 6   1965.0             Stan Getz                          Getz/Gilberto
# 7      NaN         Joao Gilberto                                    NaN
# 8   1966.0         Frank Sinatra                  September of My Years
# 9   1967.0         Frank Sinatra                    A Man and His Music
# 10  1968.0           The Beatles  Sgt. Pepper's Lonely Hearts Club Band
# 11  1969.0         Glen Campbell           By the Time I Get to Phoenix
# ...

# %%
grammys_best_album.describe()
# Out:
#               Year
# count    60.000000
# mean   1988.500000
# std      17.464249
# min    1959.000000
# 25%    1973.750000
# 50%    1988.500000
# 75%    2003.250000
# max    2018.000000

# %%
grammys_best_record.head(20)
# Out:
#     Year                               Record                     Artist  \
# 0   1959      Nel Blu Dipinto Di Blu (Volare)           Domenico Modugno
# 1   1960                       Mack the Knife                Bobby Darin
# 2   1961            Theme from A Summer Place                Percy Faith
# 3   1962                           Moon River              Henry Mancini
# 4   1963     I Left My Heart in San Francisco               Tony Bennett
# 5   1964               Days of Wine and Roses              Henry Mancini
# 6   1965                The Girl from Ipanema  Stan Getz & Joao Gilberto
# 7   1966                     A Taste of Honey                Herb Alpert
# 8   1967               Strangers in the Night              Frank Sinatra
# 9   1968                      Up, Up and Away          The 5th Dimension
# 10  1969                        Mrs. Robinson          Simon & Garfunkel
# 11  1970       Aquarius / Let the Sunshine In          The 5th Dimension
# ...

# %%
grammys_best_record.describe()
# Out:
#               Year
# count    64.000000
# mean   1990.500000
# std      18.618987
# min    1959.000000
# 25%    1974.750000
# 50%    1990.500000
# 75%    2006.250000
# max    2022.000000

# %%
money_makers_bb.head(20)
# Out:
#                         Artist  total   sales  streaming  publishing  touring  \
# 0                 Taylor Swift   23.8      10     10.600       3.200    0.000
# 1                  Post Malone   23.2  0.7125      8.100       2.000   12.400
# 2                  Celine Dion   17.5    0.25      0.290       0.024   17.000
# 3                       Eagles   16.3    0.97      2.700       1.200   11.400
# 4                Bellie Eilish   14.7     2.1      5.900       5.700    1.000
# 5                        Drake   14.2   0.635     11.700       1.900    0.000
# 6                        Queen   13.2     5.3      5.500       2.400    0.000
# 7                  The Beatles   12.9     5.2      5.100       2.600    0.000
# 8   YoungBoy Never Broke Again   11.9   0.126     10.000       1.700    0.129
# 9                     Lil Baby   11.7   0.152      9.100       2.200    0.253
# 10                  The Weeknd   10.4     1.5      7.300       1.600    0.000
# ...

# %%
money_makers_bb.describe()
# Out:
#             total   streaming  publishing     touring        year
# count  120.000000  120.000000  120.000000  120.000000   120.00000
# mean    17.236417    4.177958    1.273400   10.227300  2020.00000
# std     12.730847    3.729153    1.028007   13.143919     0.81992
# min      5.350000    0.080000    0.003000    0.000000  2019.00000
# 25%     10.200000    1.475000    0.605750    0.000000  2019.00000
# 50%     14.050000    3.200000    1.000000    7.950000  2020.00000
# 75%     19.125000    5.617500    1.725000   13.425000  2021.00000
# max     99.600000   20.500000    5.700000   90.500000  2021.00000

# %%
richest_musicians_by_year.head(20)
# Out:
#     Year                 Musician     Nationality Earnings (Millions)  \
# 0   1987        Bruce Springsteen   United States                 $56
# 1   1988        Michael Jackson *   United States                 $97
# 2   1989        Michael Jackson *   United States                $125
# 3   1990          Michael Jackson   United States                $100
# 4   1991  New Kids on the Block *   United States                $115
# 5   1992    New Kids on the Block   United States                 $62
# 6   1993            Guns N' Roses   United States                 $53
# 7   1994               Pink Floyd  United Kingdom                 $62
# 8   1995              The Beatles  United Kingdom                $130
# 9   1996              The Beatles  United Kingdom                $130
# 10  1997              The Beatles  United Kingdom                 $98
# 11  1998       The Rolling Stones  United Kingdom                 $57
# ...

# %%
richest_musicians_by_year.describe()
# Out:
#               Year  Adjusted earnings\n(in 2023 dollar)
# count    34.000000                            34.000000
# mean   2004.117647                           178.382353
# std      10.377028                           116.816877
# min    1987.000000                            69.000000
# 25%    1995.250000                           114.750000
# 50%    2004.500000                           145.000000
# 75%    2012.750000                           204.250000
# max    2021.000000                           710.000000
